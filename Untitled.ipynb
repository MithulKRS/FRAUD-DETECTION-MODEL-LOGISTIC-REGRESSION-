# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("synthetic_fraud_dataset.csv")

# %%
data
# Out:
#       transaction_id  user_id       amount transaction_type merchant_category  \
# 0               9608      363  4922.587542              ATM            Travel
# 1                456      692    48.018303               QR              Food
# 2               4747      587   136.881960           Online            Travel
# 3               6934      445    80.534719              POS          Clothing
# 4               1646      729   120.041158           Online           Grocery
# ...              ...      ...          ...              ...               ...
# 9995            1076      482    58.366442              POS          Clothing
# 9996            4995      904   139.502160              POS            Travel
# 9997            3485      527    71.012122           Online            Travel
# 9998            7922      771    21.031405               QR           Grocery
# 9999            6451      429    54.028632              ATM       Electronics
#
# ...

# %%
data.head()
# Out:
#    transaction_id  user_id       amount transaction_type merchant_category  \
# 0            9608      363  4922.587542              ATM            Travel
# 1             456      692    48.018303               QR              Food
# 2            4747      587   136.881960           Online            Travel
# 3            6934      445    80.534719              POS          Clothing
# 4            1646      729   120.041158           Online           Grocery
#
#   country  hour  device_risk_score  ip_risk_score  is_fraud
# 0      TR    12           0.992347       0.947908         1
# 1      US    21           0.168571       0.224057         0
# 2      TR    14           0.296127       0.125058         0
# 3      TR    23           0.124801       0.159243         0
# 4      FR    16           0.098129       0.027542         0

# %%
data.describe()
# Out:
#        transaction_id       user_id        amount          hour  \
# count     10000.00000  10000.000000  10000.000000  10000.000000
# mean       4999.50000    500.058700    178.142763     14.247100
# std        2886.89568    288.328495    531.647950      5.347383
# min           0.00000      0.000000      1.000000      0.000000
# 25%        2499.75000    247.000000     65.084753     10.000000
# 50%        4999.50000    503.000000    101.686510     14.000000
# 75%        7499.25000    750.250000    138.280872     19.000000
# max        9999.00000    999.000000  11628.213881     23.000000
#
#        device_risk_score  ip_risk_score      is_fraud
# count       10000.000000   10000.000000  10000.000000
# mean            0.183773       0.184669      0.050000
# std             0.177381       0.175772      0.217956
# min             0.000030       0.000009      0.000000
# 25%             0.075721       0.077762      0.000000
# 50%             0.156583       0.158290      0.000000
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.plot.scatter(x="ip_risk_score",y="is_fraud")
# Out:
# <Axes: xlabel='ip_risk_score', ylabel='is_fraud'>

# %%
df=data[['is_fraud','device_risk_score','ip_risk_score','amount']]
correlation_matrix = df.corr()

# %%
correlation_matrix
data
# Out:
#       transaction_id  user_id       amount transaction_type merchant_category  \
# 0               9608      363  4922.587542              ATM            Travel
# 1                456      692    48.018303               QR              Food
# 2               4747      587   136.881960           Online            Travel
# 3               6934      445    80.534719              POS          Clothing
# 4               1646      729   120.041158           Online           Grocery
# ...              ...      ...          ...              ...               ...
# 9995            1076      482    58.366442              POS          Clothing
# 9996            4995      904   139.502160              POS            Travel
# 9997            3485      527    71.012122           Online            Travel
# 9998            7922      771    21.031405               QR           Grocery
# 9999            6451      429    54.028632              ATM       Electronics
#
# ...

# %%
from sklearn.model_selection import StratifiedShuffleSplit
y=data['is_fraud']
X=data.drop('is_fraud', axis=1)

# %%
for train_index, test_index in sss.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
training=X_train.copy()
testing=X_test.copy()

# %%
tr_num=training.drop(['transaction_id','user_id','transaction_type','country','merchant_category'],axis=1)
t_num=testing.drop(['transaction_id','user_id','transaction_type','country','merchant_category'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_num = scaler.fit_transform(tr_num)
test_num=scaler.fit_transform(t_num)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000) # Increase max_iter if convergence warnings occur
model.fit(train_num, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(test_num)
accuracy = accuracy_score(y_test, y_pred)

# %%
y_train
# Out:
# 1771    0
# 5149    0
# 456     0
# 1343    0
# 5957    0
#        ..
# 4102    0
# 3694    0
# 6986    0
# 6651    0
# 2207    0
# Name: is_fraud, Length: 8000, dtype: int64

# %%
y_test
# Out:
# 1233    0
# 5813    0
# 9740    0
# 6393    0
# 3504    0
#        ..
# 7011    0
# 2357    0
# 3806    0
# 227     0
# 323     0
# Name: is_fraud, Length: 2000, dtype: int64

# %%
arr=[[1786666.50289,11,0.09028,0.613008]]

# %%
res=model.predict(arr)

# %% [raw]
# res

# %%
print(res)
# Out:
# [1]

# %%
print(f"accuracy is {accuracy*100}%")
# Out:
# accuracy is 100.0%
